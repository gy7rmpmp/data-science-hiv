# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
# plt.style.available

# %%
df = pd.read_csv('https://od.cdc.gov.tw/eic/Age_County_Gender_044.csv')

# %%
df=df[df['診斷年份']>2016]
df=df[df['診斷年份']<2022]
df
# Out:
#         確定病名  診斷年份  診斷月份   縣市 性別   國籍    年齡層  確定病例數
# 12929  ＨＩＶ感染  2017     1  台中市  F  本國籍  50-54      1
# 12930  ＨＩＶ感染  2017     1  台中市  M  本國籍  15-19      3
# 12931  ＨＩＶ感染  2017     1  台中市  M  本國籍  20-24      6
# 12932  ＨＩＶ感染  2017     1  台中市  M  本國籍  25-29      9
# 12933  ＨＩＶ感染  2017     1  台中市  M  本國籍  30-34      3
# ...      ...   ...   ...  ... ..  ...    ...    ...
# 17266  ＨＩＶ感染  2021     9  彰化縣  M  本國籍  20-24      1
# 17267  ＨＩＶ感染  2021     9  彰化縣  M  本國籍  25-29      1
# 17268  ＨＩＶ感染  2021     9  彰化縣  M  本國籍  35-39      1
# 17269  ＨＩＶ感染  2021     9  彰化縣  M  本國籍  45-49      1
# 17270  ＨＩＶ感染  2021     9  彰化縣  M  本國籍    70+      1
#
# [4342 rows x 8 columns]

# %%
df = df.rename(columns={'確定病名':'hiv','診斷年份':'year','診斷月份':'month','縣市':'county','性別':'sex','國籍':'tw',
                          '年齡層':'age','確定病例數':'N'})
df.head()
# Out:
#          hiv  year  month county sex   tw    age  N
# 12929  ＨＩＶ感染  2017      1    台中市   F  本國籍  50-54  1
# 12930  ＨＩＶ感染  2017      1    台中市   M  本國籍  15-19  3
# 12931  ＨＩＶ感染  2017      1    台中市   M  本國籍  20-24  6
# 12932  ＨＩＶ感染  2017      1    台中市   M  本國籍  25-29  9
# 12933  ＨＩＶ感染  2017      1    台中市   M  本國籍  30-34  3

# %%
for i in df.sex: 
    if i  == 'M': 
        df.sex.replace(i, 1, inplace = True) 
    elif i  == 'F':
        df.sex.replace(i, 2, inplace = True) 
        
for i in df.age: 
    if  i  == '0':
        df.age.replace(i, 1, inplace = True)
    elif i  == '1':
        df.age.replace(i, 2, inplace = True)
    elif i  == '2':
        df.age.replace(i, 2, inplace = True)
    elif i  == '3':
        df.age.replace(i, 2, inplace = True)
    elif i  == '4':
        df.age.replace(i, 2, inplace = True)
    elif i  == '5-9':
        df.age.replace(i, 3, inplace = True) 
    elif i  == '10-14':
        df.age.replace(i, 4, inplace = True) 
    elif i  == '15-19':
        df.age.replace(i, 5, inplace = True) 
    elif i  == '20-24':
        df.age.replace(i, 6, inplace = True) 
    elif i  == '25-29':
        df.age.replace(i, 7, inplace = True) 
    elif i  == '30-34':
        df.age.replace(i, 8, inplace = True) 
    elif i  == '35-39':
        df.age.replace(i, 9, inplace = True) 
    elif i  == '40-44':
        df.age.replace(i, 10, inplace = True) 
    elif i  == '45-49':
        df.age.replace(i, 11, inplace = True)
    elif i  == '50-54':
        df.age.replace(i, 12, inplace = True) 
    elif i  == '55-59':
        df.age.replace(i, 13, inplace = True) 
    elif i  == '60-64':
        df.age.replace(i, 14, inplace = True) 
    elif i  == '65-69':
        df.age.replace(i, 15, inplace = True) 
    elif i  == '70+':
        df.age.replace(i, 16, inplace = True) 

for i in df.county: 
    if i  == '基隆市':
        df.county.replace(i, 1, inplace = True) 
    elif i  == '台北市':
        df.county.replace(i, 2, inplace = True) 
    elif i  == '新北市':
        df.county.replace(i, 3, inplace = True) 
    elif i  == '宜蘭縣':
        df.county.replace(i, 4, inplace = True) 
    elif i  == '桃園市':
        df.county.replace(i, 5, inplace = True) 
    elif i  == '新竹縣':
        df.county.replace(i, 6, inplace = True)
    elif i  == '新竹市':
        df.county.replace(i, 7, inplace = True) 
    elif i  == '苗栗縣':
        df.county.replace(i, 8, inplace = True) 
    elif i  == '台中市':
        df.county.replace(i, 9, inplace = True) 
    elif i  == '彰化縣':
        df.county.replace(i, 10, inplace = True)
    elif i  == '南投縣':
        df.county.replace(i, 11, inplace = True) 
    elif i  == '雲林縣':
        df.county.replace(i, 12, inplace = True) 
    elif i  == '嘉義縣':
        df.county.replace(i, 13, inplace = True) 
    elif i  == '嘉義市':
        df.county.replace(i, 14, inplace = True)
    elif i  == '台南市':
        df.county.replace(i, 15, inplace = True) 
    elif i  == '高雄市':
        df.county.replace(i, 16, inplace = True) 
    elif i  == '屏東縣':
        df.county.replace(i, 17, inplace = True) 
    elif i  == '花蓮縣':
        df.county.replace(i, 18, inplace = True) 
    elif i  == '台東縣':
        df.county.replace(i, 19, inplace = True)
    elif i  == '連江縣':
        df.county.replace(i, 20, inplace = True) 
    elif i  == '金門縣':
        df.county.replace(i, 21, inplace = True)
    elif i  == '澎湖縣':
        df.county.replace(i, 22, inplace = True)

# %%
df_s = df.groupby(['age','year'])['N'].sum().reset_index()
df_s
# Out:
#     age  year   N
# 0     1  2017   1
# 1     3  2017   1
# 2     4  2017   1
# 3     4  2019   2
# 4     4  2020   1
# ..  ...   ...  ..
# 60   16  2017  10
# 61   16  2018   2
# 62   16  2019   5
# 63   16  2020   8
# 64   16  2021   8
#
# [65 rows x 3 columns]

# %%
df_s = df_s.groupby(['age'])['N'].mean()
df_s
# Out:
# age
# 1       1.000000
# 3       1.000000
# 4       1.333333
# 5      74.000000
# 6     359.200000
# 7     466.400000
# 8     364.600000
# 9     228.800000
# 10    140.000000
# 11     93.600000
# 12     61.200000
# 13     33.600000
# 14     19.200000
# 15     11.000000
# 16      6.600000
# Name: N, dtype: float64

# %%
df_s.plot(kind='bar',rot=45,figsize=(8.5,7))
plt.tight_layout()
plt.show()

# %%
df_e = df.groupby(['age','year','sex'])['N'].sum().reset_index()
df_e
# Out:
#      age  year  sex  N
# 0      1  2017    1  1
# 1      3  2017    2  1
# 2      4  2017    1  1
# 3      4  2019    2  2
# 4      4  2020    1  1
# ..   ...   ...  ... ..
# 116   16  2018    1  2
# 117   16  2019    1  5
# 118   16  2020    1  5
# 119   16  2020    2  3
# 120   16  2021    1  8
#
# [121 rows x 4 columns]

# %%
df_e = df_e.groupby(['age','sex'])['N'].mean().reset_index()
df_e
# Out:
#     age  sex       N
# 0     1    1    1.00
# 1     3    2    1.00
# 2     4    1    1.00
# 3     4    2    2.00
# 4     5    1   72.20
# 5     5    2    2.25
# 6     6    1  354.00
# 7     6    2    5.20
# 8     7    1  458.00
# 9     7    2    8.40
# 10    8    1  355.20
# 11    8    2    9.40
# 12    9    1  217.60
# 13    9    2   11.20
# 14   10    1  131.40
# 15   10    2    8.60
# 16   11    1   89.40
# 17   11    2    4.20
# 18   12    1   56.60
# 19   12    2    4.60
# 20   13    1   29.80
# 21   13    2    3.80
# 22   14    1   15.60
# 23   14    2    3.60
# 24   15    1    8.80
# 25   15    2    2.20
# 26   16    1    5.60
# 27   16    2    2.50

# %%
import seaborn as sns
ax = sns.barplot(x='age', y='N', hue='sex', data=df_e)
